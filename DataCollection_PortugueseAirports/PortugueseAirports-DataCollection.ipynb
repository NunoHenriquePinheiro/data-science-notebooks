# %% [markdown]
# # Project - Data Collection Methodologies
#
# **Postgraduate studies in Data Science**<br/>
# **Student:** Nuno Henrique Pereira Martins Pinheiro<br/>
#
# ## Airports in Portugal
#
# This project gathers data about airports in Portugal.
# A generic list of them is to be gotten and data regarding their identification, location and contacts is to be persisted.
# Data related with the runways of each airport and the availability of their schedules is to be exported.
#
# ### Business Requirements
#
# 1. List all airports in Portugal;
# 2. Fetch the airports' identification codes, location, contacts and other basic information;
# 3. Fetch each airports' runways information - list and identify their runways, the measures of each one and other data;
# 4. Check the availability status of schedules' information for each airport - the health response of different providers;
# 5. Export the data on airports' runways (in 3) and schedules' availability status (in 4) to two different JSON files;
# 6. Persist the airports' information (in 1 and 2) in a relational database - one only table.
#
# ### Technical Requirements
#
# - **Business layer:** Python, Jupyter Notebook
# - **Export information to:** JSON files
# - **Persistence layer:** SQLite
#
# - List airports in Portugal, with identification codes and basic information: `web scraping from https://en.wikipedia.org/wiki/List_of_airports_in_Portugal` (or an offline option with a copy of the webpage's content)
# - Get airports' describing data from a REST endpoint: `GET https://airport-info.p.rapidapi.com/airport?icao={icao_code}`
# - Get airports' runaways from a REST endpoint: `GET https://aerodatabox.p.rapidapi.com/airports/icao/{icao_code}/runways`
# - Get the availability status of airport's schedules from a REST endpoint: `GET https://aerodatabox.p.rapidapi.com/health/services/airports/{icao_code}/feeds`
#
# - Save the obtained information:
#     - JSON files:
#         - Airports' runways - file named *airport-runways.json*;
#         - Schedules' availability - file named *airport-schedules-status.json*;
#     - Database Persistence:
#         - Airports' list and detailed information - table named *Airports*, with *ICAO code* as primary key. The table must be recreated, each time this notebook runs, since it is for demonstration.

# %% [markdown]
# ### Development

# %%
from bs4 import BeautifulSoup
from os.path import join
import asyncio
import json
import os
import pandas as pd
import requests
import sqlite3

# %% [markdown]
# #### Get a collection of Portuguese Airports internationally codified, with web scraping

# %%
def get_html_from_url(url):
    """
    Summary: Gets HTML content from a given URL.
    Params: 'url' - The URL to get the HTML from.
    Returns: A parsed HTML.
    """
    raw_html = requests.get(url).content
    return BeautifulSoup(raw_html, 'html.parser')

def get_html_from_file(file_location):
    """
    Summary: Gets HTML content from an existing file.
    Params: 'file_location' - Location of the file to get the HTML from.
    Returns: A parsed HTML.
    """
    with open(file_location.replace('"', ''), encoding='utf8') as infile:
        return BeautifulSoup(infile.read(), 'html.parser')

def get_html(from_location, is_online):
    """
    Summary: Gets HTML content from a given location, depending on being online or offline.
    Params: 'from_location' - Location to get the HTML from. If online, it must be an URL. If offline, it must be a file location.
            'is_online' - Boolean stating if the HTML is to get from an online location. True, if online; false, if offline.
    Returns: A parsed HTML.
    """
    return get_html_from_url(from_location) if is_online else get_html_from_file(from_location)

# %%
# True, to fetch from online website. False to fetch from files in 'airport_website' folder
is_online = True

html_location = 'https://en.wikipedia.org/wiki/List_of_airports_in_Portugal' if is_online else join(os.getcwd(), 'airport_website\\"List of airports in Portugal - Wikipedia.html"')

parsed_html = get_html(html_location, is_online)

# %%
table_class = 'wikitable sortable' if is_online else 'wikitable sortable jquery-tablesorter'

airports_table = parsed_html.find_all('table', class_=table_class)

# %%
def build_airport_dictionary(icao, iata, city, region, description):
    """
    Summary: Builds a dictionary with the provided airport information.
    Params: 'icao' - Airport's ICAO code.
            'iata' - Airport's IATA code.
            'city' - Airport's city.
            'region' - Airport's region.
            'description' - Airport's description.
    Returns: A dictionary with the params' labels as keys to the matching input values.
    """
    return {'icao': icao, 'iata': iata, 'city': city, 'region': region, 'description': description}

def get_valid_row_attributes(table_row):
    """
    Summary: Gets the valid attributes from a given HTML table row - based on the tag "td".
    Params: 'table_row' - The table row.
    Returns: An array of contents extracted from the row.
    """
    array_to_exclude = ['\n']
    row_attributes = airport_row.find_all('td')
    row_attributes = [attribute.contents for attribute in row_attributes]
    row_attributes = [attribute for attribute in row_attributes if attribute != array_to_exclude]
    return row_attributes


# Array of dictionaries - each of them defines an airport

airports_dictionaries = []

for airport_row in airports_table[0].find_all('tr'):
    row_attributes = get_valid_row_attributes(airport_row)
    
    # Exclude airports without ICAO, but include the ones without IATA
    is_airport_without_iata = len(row_attributes) == 4 and len(row_attributes[2]) == 1
    is_airport_with_iata = len(row_attributes) == 5 and len(row_attributes[2]) == 1
    
    if is_airport_without_iata:
        icao = str(row_attributes[2][-1]).strip('\n').strip(' ')
        iata = None
        city = row_attributes[0][0].contents[0].strip('\n').strip(' ')
        region = row_attributes[1][0].contents[0].strip('\n').strip(' ')
        description = row_attributes[3][0].contents[0].strip('\n').strip(' ')
        
        airports_dictionaries.append(build_airport_dictionary(icao, iata, city, region, description))
    
    elif is_airport_with_iata:
        icao = str(row_attributes[2][-1]).strip('\n').strip(' ')
        iata = ''.join([c for c in row_attributes[3][-1] if c.isupper()])[-3:4].strip('\n').strip(' ')
        city = row_attributes[0][0].contents[0].strip('\n').strip(' ')
        region = row_attributes[1][0].contents[0].strip('\n').strip(' ')
        description = row_attributes[4][0].contents[0].strip('\n').strip(' ')
        
        airports_dictionaries.append(build_airport_dictionary(icao, iata, city, region, description))

# %%
# Dataframe with the Portuguese airports' basic information

airports = pd.DataFrame(airports_dictionaries)

# Drop duplicates since some airports may be registered for civil and militar uses, for example.
# However, they are the same airport, with the same ICAO
airports.drop_duplicates(subset='icao', keep='first', inplace=True)
airports = airports.reset_index(drop=True)

airports
# Out:
#     icao  iata                city    region  \
# 0   LPBJ   BYJ                Beja  Alentejo
# 1   LPBR   BGZ               Braga     Norte
# 2   LPBG   BGC            Bragança     Norte
# 3   LPCS   CAT             Cascais    Lisboa
# 4   LPCH   CHV              Chaves     Norte
# 5   LPCO   CBP             Coimbra    Centro
# 6   LPIN  None             Espinho     Norte
# 7   LPEV  None               Évora  Alentejo
# 8   LPFR   FAO                Faro   Algarve
# 9   LPVL  None                Maia     Norte
# 10  LPMI  None           Mirandela     Norte
# 11  LPMF  None         Monfortinho    Centro
# 12  LPMO   QLR           Montargil  Alentejo
# 13  LPPT   LIS              Lisbon    Lisboa
# 14  LPPM   PRM            Portimão   Algarve
# 15  LPPR   OPO               Porto     Norte
# 16  LPPV  None        Castro Marim   Algarve
# 17  LPSC  None          Santa Cruz    Centro
# 18  LPVR   VRL           Vila Real     Norte
# 19  LPVZ   VSE               Viseu    Centro
# 20  LPAR  None             Alverca    Lisboa
# 21  LPMR  None          Monte Real    Centro
# 22  LPMT   PAF             Montijo    Lisboa
# 23  LPOT  None                 Ota    Centro
# 24  LPOV  None                Ovar    Centro
# 25  LP77  None     Santa Margarida    Centro
# 26  LPST  None              Sintra    Lisboa
# 27  LPTN  None              Tancos    Centro
# 28  LPCR   CVU        Corvo Island    Azores
# 29  LPHR   HOR        Faial Island    Azores
# 30  LPFL   FLW       Flores Island    Azores
# 31  LPGR   GRW     Graciosa Island    Azores
# 32  LPPI   PIX         Pico Island    Azores
# 33  LPAZ   SMA         Santa Maria    Azores
# 34  LPSJ   SJZ    São Jorge Island    Azores
# 35  LPPD   PDL   São Miguel Island    Azores
# 36  LPLA   TER     Terceira Island    Azores
# 37  LPMA   FNC      Madeira Island   Madeira
# 38  LPPS   PXO  Porto Santo Island   Madeira
#
#                           description
# 0                        Beja Airport
# 1                       Braga Airport
# 2                    Bragança Airport
# 3     Lisbon-Cascais Regional Airport
# 4                      Chaves Airport
# 5                     Coimbra Airport
# 6                     Espinho Airport
# 7                       Évora Airport
# 8                        Faro Airport
# 9                        Maia Airport
# 10                  Mirandela Airport
# 11                Monfortinho Airport
# 12                   Morargil Airport
# 13                     Lisbon Airport
# 14                   Portimão Airport
# 15      Francisco Sá Carneiro Airport
# 16                Praia Verde Airport
# 17                 Santa Cruz Airport
# 18                  Vila Real Airport
# 19                      Viseu Airport
# 20                    Alverca Airbase
# 21                Monte Real Air Base
# 22                    Montijo Airbase
# 23                        Ota Airbase
# 24                       Ovar Airbase
# 25       Santa Margarida Army Airbase
# 26                     Sintra Airbase
# 27                     Tancos Airbase
# 28                      Corvo Airport
# 29                      Horta Airport
# 30                     Flores Airport
# 31                   Graciosa Airport
# 32                       Pico Airport
# 33                Santa Maria Airport
# 34                  São Jorge Airport
# 35              João Paulo II Airport
# 36                     Lajes Air Base
# 37  Cristiano Ronaldo Madeira Airport
# 38                Porto Santo Airport

# %% [markdown]
# #### Get detailed information for each airport, using 3 API endpoints

# %%
def get_http_request(url, headers, query_params=None):
    """
    Summary: Performs a GET HTTP request.
    Params: 'url' - The URL of the request.
            'headers' - The headers of the request.
            'query_params' - Query string parameters [default is None].
    Returns: The response of the HTTP request. If any unsuccessful response is returned, or if an exception occurs, a message is printed.
    """
    result = None
    
    try:
        if (query_params == None or len(query_params) == 0):
            result = requests.request('GET', url, headers=headers)
        else:
            result = requests.request('GET', url, headers=headers, params=query_params)
            
        if ((not result.ok) or result.is_redirect):
            print(f'GET response was not successful. || URL: {url} || HTTP status code: {result.status_code}')
            result = None
            
    except Exception as exc:
        print(f'The GET request raised an exception: {exc!r}')
    
    return result

def get_airport_info(icao_code):
    """
    Summary: GET request to 'https://airport-info.p.rapidapi.com/airport?icao={icao_code}'.
             Obtains basic information about a given airport, based on its ICAO code.
    Params: 'icao_code' - The ICAO code.
    Returns: HTTP response with information summary about the airport.
    """
    url = 'https://airport-info.p.rapidapi.com/airport'
    query_params = { 'icao': icao_code }
    headers = {
        'x-rapidapi-key': 'the key', # auth key is required
        'x-rapidapi-host': 'airport-info.p.rapidapi.com'
    }
    
    return get_http_request(url, headers, query_params)

def get_airport_runways(icao_code):
    """
    Summary: GET request to 'https://aerodatabox.p.rapidapi.com/airports/icao/{icao_code}/runways'.
             Based on a given airport's ICAO, it gets the airport's runways information.
    Params: 'icao_code' - The ICAO code.
    Returns: HTTP response with information summary on the airport's runways.
    """
    url = f'https://aerodatabox.p.rapidapi.com/airports/icao/{icao_code}/runways'
    headers = {
        'x-rapidapi-key': 'the key', # auth key is required
        'x-rapidapi-host': 'aerodatabox.p.rapidapi.com'
    }
    
    return get_http_request(url, headers)

def get_airport_schedules_status(icao_code):
    """
    Summary: GET request to 'https://aerodatabox.p.rapidapi.com/health/services/airports/{icao_code}/feeds'.
             Based on a given airport's ICAO, it gets availability status on the airport's schedules, in different providers.
    Params: 'icao_code' - The ICAO code.
    Returns: HTTP response with the availability status of information related with the airport's schedules.
    """
    url = f'https://aerodatabox.p.rapidapi.com/health/services/airports/{icao_code}/feeds'
    headers = {
        'x-rapidapi-key': 'the key', # auth key is required
        'x-rapidapi-host': 'aerodatabox.p.rapidapi.com'
    }
    
    return get_http_request(url, headers)

# %%
# Dictionaries with information related with:
# - airport descriptions, contacts, location and others
# - airport runways
# - availability status of airports' schedules

airport_info_dict = {}
airport_runways_dict = {}
airport_schedules_status_dict = {}

# Add elements to the dictionaries asynchronously to reduce operating time - the tasks can be parallelly scheduled and ran

async def add_airport_info_async(icao):
    response_info = get_airport_info(icao)
    if (response_info is not None):
        airport_info_dict[icao] = json.loads(response_info.text)
        
async def add_airport_runways_async(icao):
    response_runways = get_airport_runways(icao)
    if (response_runways is not None):
        airport_runways_dict[icao] = json.loads(response_runways.text)
        
async def add_airport_schedules_async(icao):
    response_schedules = get_airport_schedules_status(icao)
    if (response_schedules is not None):
        airport_schedules_status_dict[icao] = json.loads(response_schedules.text)

        
tasks = []

print('Start airports iterations')
for icao in airports['icao']:
    print(icao)
    tasks.append(asyncio.create_task(add_airport_info_async(icao)))
    tasks.append(asyncio.create_task(add_airport_runways_async(icao)))
    tasks.append(asyncio.create_task(add_airport_schedules_async(icao)))
    
print('Awaiting tasks')    
await asyncio.gather(*tasks)
# Out:
# Start airports iterations
# LPBJ
# LPBR
# LPBG
# LPCS
# LPCH
# LPCO
# LPIN
# LPEV
# LPFR
# LPVL
# LPMI
# LPMF
# LPMO
# LPPT
# LPPM
# LPPR
# LPPV
# LPSC
# LPVR
# LPVZ
# LPAR
# LPMR
# LPMT
# LPOT
# LPOV
# LP77
# LPST
# LPTN
# LPCR
# LPHR
# LPFL
# LPGR
# LPPI
# LPAZ
# LPSJ
# LPPD
# LPLA
# LPMA
# LPPS
# Awaiting tasks
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPCS/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPIN/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPEV/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPVL/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPMI/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPMF/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPMO/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPPV/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPSC/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPAR/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPMR/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPMT/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPOT/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPOV/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LP77/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPST/feeds || HTTP status code: 404
# GET response was not successful. || URL: https://aerodatabox.p.rapidapi.com/health/services/airports/LPTN/feeds || HTTP status code: 404
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
airport_info_dict
# Out:
# {'LPBJ': {'id': 1100,
#   'iata': 'BYJ',
#   'icao': 'LPBJ',
#   'name': 'Beja Airport',
#   'location': 'Beja, Portugal',
#   'street_number': '',
#   'street': '',
#   'city': '',
#   'county': '',
#   'state': 'Beja',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '7780-745',
#   'phone': '+351 284 001 020',
#   'latitude': 38.063667,
#   'longitude': -7.9393034,
#   'uct': 60,
#   'website': ''},
#  'LPBR': {'id': 695,
#   'iata': 'BGZ',
#   'icao': 'LPBR',
#   'name': 'Braga Airport',
#   'location': 'Braga, Portugal',
#   'street_number': '',
#   'street': 'Rua do Carregal',
#   'city': 'Palmeira',
#   'county': '',
#   'state': 'Braga',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '4700-688',
#   'phone': '+351 253 626 530',
#   'latitude': 41.586994,
#   'longitude': -8.442929,
#   'uct': 60,
#   'website': 'https://aeroclubebraga.pt/'},
#  'LPBG': {'id': 673,
#   'iata': 'BGC',
#   'icao': 'LPBG',
#   'name': 'Bragança Airport',
#   'location': 'Bragança, Portugal',
#   'street_number': '',
#   'street': 'Aeródromo de Bragança',
#   'city': 'Bragança',
#   'county': '',
#   'state': 'Bragança',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '5300-000',
#   'phone': '+351 273 381 175',
#   'latitude': 41.85719,
#   'longitude': -6.70726,
#   'uct': 60,
#   'website': 'https://www.cm-braganca.pt/pages/125'},
#  'LPCS': {'id': 1155,
#   'iata': 'CAT',
#   'icao': 'LPCS',
#   'name': 'Cascais Municipal Aerodrome',
#   'location': 'Cascais, Portugal',
#   'street_number': '',
#   'street': '',
#   'city': 'São Domingos de Rana',
#   'county': '',
#   'state': 'Lisboa',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '2785',
#   'phone': '+351 21 445 7300',
#   'latitude': 38.721943,
#   'longitude': -9.353611,
#   'uct': 60,
#   'website': 'http://aerodromo-cascais.pt/'},
#  'LPCH': {'id': 1313,
#   'iata': 'CHV',
#   'icao': 'LPCH',
#   'name': 'Chaves Airport',
#   'location': 'Chaves, Portugal',
#   'street_number': 'S/N',
#   'street': 'Rua Dom Gualdim Pais',
#   'city': 'Chaves',
#   'county': '',
#   'state': 'Vila Real',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '5400-298',
#   'phone': '+351 276 321 995',
#   'latitude': 41.72512,
#   'longitude': -7.4663243,
#   'uct': 60,
#   'website': 'http://www.chaves.pt/pages/439'},
#  'LPCO': {'id': 1176,
#   'iata': 'CBP',
#   'icao': 'LPCO',
#   'name': 'Coimbra Airport',
#   'location': 'Coimbra, Portugal',
#   'street_number': '',
#   'street': 'Estrada Ponte',
#   'city': 'Antanhol',
#   'county': '',
#   'state': 'Coimbra',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '3040-575',
#   'phone': '+351 239 947 235',
#   'latitude': 40.15911,
#   'longitude': -8.471043,
#   'uct': 60,
#   'website': ''},
#  'LPIN': {'error': {'text': 'No airport found'}},
#  'LPEV': {'error': {'text': 'No airport found'}},
#  'LPFR': {'id': 2238,
#   'iata': 'FAO',
#   'icao': 'LPFR',
#   'name': 'Faro Airport',
#   'location': 'Faro, Portugal',
#   'street_number': '',
#   'street': '',
#   'city': 'Faro',
#   'county': '',
#   'state': 'Faro District',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '8001-701',
#   'phone': '+351 289 800 800',
#   'latitude': 37.017597,
#   'longitude': -7.96972,
#   'uct': 60,
#   'website': 'http://www.ana.pt/pt-PT/Aeroportos/Algarve/Faro/Paginas/HomeFaro.aspx'},
#  'LPVL': {'error': {'text': 'No airport found'}},
#  'LPMI': {'error': {'text': 'No airport found'}},
#  'LPMF': {'error': {'text': 'No airport found'}},
#  'LPMO': {'error': {'text': 'No airport found'}},
#  'LPPT': {'id': 4202,
#   'iata': 'LIS',
#   'icao': 'LPPT',
#   'name': 'Lisbon Portela Airport',
#   'location': 'Lisbon, Portugal',
#   'street_number': '',
#   'street': 'Alameda das Comunidades Portuguesas',
#   'city': 'Lisboa',
#   'county': '',
#   'state': 'Lisboa',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '1700-111',
#   'phone': '+351 21 841 3500',
#   'latitude': 38.775593,
#   'longitude': -9.135366,
#   'uct': 60,
#   'website': 'http://www.ana.pt/pt-PT/Aeroportos/Lisboa/Lisboa/Paginas/HomeLisboa.aspx'},
#  'LPPM': {'id': 6092,
#   'iata': 'PRM',
#   'icao': 'LPPM',
#   'name': 'Portimão Airport',
#   'location': 'Portimão, Portugal',
#   'street_number': '',
#   'street': '',
#   'city': 'Alvor',
#   'county': '',
#   'state': 'Faro',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '8500-059',
#   'phone': '+351 932 001 009',
#   'latitude': 37.147663,
#   'longitude': -8.580112,
#   'uct': 60,
#   'website': 'http://www.airemotions.com/'},
#  'LPPR': {'id': 5640,
#   'iata': 'OPO',
#   'icao': 'LPPR',
#   'name': 'Francisco de Sá Carneiro Airport',
#   'location': 'Porto, Portugal',
#   'street_number': '',
#   'street': '',
#   'city': 'Maia',
#   'county': '',
#   'state': 'Porto District',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '4470-558',
#   'phone': '+351 22 943 2400',
#   'latitude': 41.24212,
#   'longitude': -8.678552,
#   'uct': 60,
#   'website': 'http://www.ana.pt/pt-PT/Aeroportos/Porto/Porto/Paginas/HomePorto.aspx'},
#  'LPPV': {'error': {'text': 'No airport found'}},
#  'LPSC': {'error': {'text': 'No airport found'}},
#  'LPVR': {'id': 8055,
#   'iata': 'VRL',
#   'icao': 'LPVR',
#   'name': 'Vila Real Airport',
#   'location': 'Vila Real, Portugal',
#   'street_number': '',
#   'street': '',
#   'city': 'Vila Real',
#   'county': '',
#   'state': 'Vila Real District',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '5000',
#   'phone': '+351 259 336 620',
#   'latitude': 41.275814,
#   'longitude': -7.719441,
#   'uct': 60,
#   'website': ''},
#  'LPVZ': {'id': 8061,
#   'iata': 'VSE',
#   'icao': 'LPVZ',
#   'name': 'Viseu Airport',
#   'location': 'Viseu, Portugal',
#   'street_number': '',
#   'street': 'Avenida Aeródromo',
#   'city': 'Viseu',
#   'county': '',
#   'state': 'Viseu',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '3515',
#   'phone': '+351 232 459 849',
#   'latitude': 40.727264,
#   'longitude': -7.8905206,
#   'uct': 60,
#   'website': 'https://www.cm-viseu.pt/'},
#  'LPAR': {'error': {'text': 'No airport found'}},
#  'LPMR': {'error': {'text': 'No airport found'}},
#  'LPMT': {'error': {'text': 'No airport found'}},
#  'LPOT': {'error': {'text': 'No airport found'}},
#  'LPOV': {'error': {'text': 'No airport found'}},
#  'LP77': {'error': {'text': 'No airport found'}},
#  'LPST': {'error': {'text': 'No airport found'}},
#  'LPTN': {'error': {'text': 'No airport found'}},
#  'LPCR': {'id': 1611,
#   'iata': 'CVU',
#   'icao': 'LPCR',
#   'name': 'Corvo Airport',
#   'location': 'Corvo Island, Azores, Portugal',
#   'street_number': '',
#   'street': 'Corvo - V. Corvo - Flores',
#   'city': 'Corvo',
#   'county': '',
#   'state': 'Açores',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9980-000',
#   'phone': '+351 292 590 310',
#   'latitude': 39.67065,
#   'longitude': -31.113253,
#   'uct': 0,
#   'website': 'http://www.sata.pt/'},
#  'LPHR': {'id': 2976,
#   'iata': 'HOR',
#   'icao': 'LPHR',
#   'name': 'Horta Airport',
#   'location': 'Horta, Azores, Portugal',
#   'street_number': '',
#   'street': 'Castelo Branco',
#   'city': 'Castelo Branco, Horta',
#   'county': '',
#   'state': 'Açores',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9900-321',
#   'phone': '+351 292 943 511',
#   'latitude': 38.52,
#   'longitude': -28.716389,
#   'uct': 0,
#   'website': 'http://www.ana.pt/pt-PT/Aeroportos/Acores/Horta/Paginas/Homepage-Horta.aspx'},
#  'LPFL': {'id': 2327,
#   'iata': 'FLW',
#   'icao': 'LPFL',
#   'name': 'Flores Airport',
#   'location': 'Flores Island, Azores, Portugal',
#   'street_number': '',
#   'street': '',
#   'city': 'Santa Cruz Das Flores',
#   'county': '',
#   'state': 'Azores',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9970-320',
#   'phone': '+351 800 201 201',
#   'latitude': 39.459354,
#   'longitude': -31.131304,
#   'uct': 0,
#   'website': 'http://www.ana.pt/pt-PT/Aeroportos/Acores/Flores/Paginas/Homepage-Flores.aspx'},
#  'LPGR': {'id': 2697,
#   'iata': 'GRW',
#   'icao': 'LPGR',
#   'name': 'Graciosa Airport',
#   'location': 'Graciosa, Azores, Portugal',
#   'street_number': '',
#   'street': 'EN1-2',
#   'city': 'Santa Cruz da Graciosa',
#   'county': '',
#   'state': 'Açores',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9880',
#   'phone': '+351 296 209 748',
#   'latitude': 39.09181,
#   'longitude': -28.031773,
#   'uct': 0,
#   'website': ''},
#  'LPPI': {'id': 5932,
#   'iata': 'PIX',
#   'icao': 'LPPI',
#   'name': 'Pico Airport',
#   'location': 'Pico Island, Azores, Portugal',
#   'street_number': '',
#   'street': 'Bandeiras',
#   'city': 'Madalena do Pico, Pico',
#   'county': '',
#   'state': 'Açores',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9950-011',
#   'phone': '+351 292 628 380',
#   'latitude': 38.55235,
#   'longitude': -28.443344,
#   'uct': 0,
#   'website': ''},
#  'LPAZ': {'id': 6877,
#   'iata': 'SMA',
#   'icao': 'LPAZ',
#   'name': 'Santa Maria Airport',
#   'location': 'Santa Maria Island, Azores, Portugal',
#   'street_number': '3249',
#   'street': 'Terminal Drive',
#   'city': 'Santa Maria',
#   'county': 'Santa Barbara County',
#   'state': 'California',
#   'country_iso': 'US',
#   'country': 'United States',
#   'postal_code': '93455',
#   'phone': '+1 805-922-1726',
#   'latitude': 34.89914,
#   'longitude': -120.44778,
#   'uct': -420,
#   'website': 'http://www.santamariaairport.com/'},
#  'LPSJ': {'id': 6825,
#   'iata': 'SJZ',
#   'icao': 'LPSJ',
#   'name': 'São Jorge Airport',
#   'location': 'São Jorge Island, Azores, Portugal',
#   'street_number': '',
#   'street': 'EN1',
#   'city': '',
#   'county': '',
#   'state': 'Açores',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9800',
#   'phone': '',
#   'latitude': 38.66562,
#   'longitude': -28.175667,
#   'uct': 0,
#   'website': ''},
#  'LPPD': {'id': 5832,
#   'iata': 'PDL',
#   'icao': 'LPPD',
#   'name': 'João Paulo II Airport',
#   'location': 'Ponta Delgada, Azores, Portugal',
#   'street_number': '',
#   'street': 'Aeroporto de Ponta Delgada',
#   'city': 'São Miguel, Açores',
#   'county': '',
#   'state': 'Açores',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9500-749',
#   'phone': '+351 296 205 400',
#   'latitude': 37.74233,
#   'longitude': -25.700388,
#   'uct': 0,
#   'website': 'https://www.aeroportopontadelgada.pt/'},
#  'LPLA': {'id': 7316,
#   'iata': 'TER',
#   'icao': 'LPLA',
#   'name': 'Lajes Field',
#   'location': 'Terceira Island, Azores, Portugal',
#   'street_number': '',
#   'street': 'Aerogare Civil das Lajes',
#   'city': 'Lajes, Praia da Vitória',
#   'county': '',
#   'state': 'Ilha de Terceira',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9760-251',
#   'phone': '+351 295 545 454',
#   'latitude': 38.75388,
#   'longitude': -27.086943,
#   'uct': 0,
#   'website': 'http://aerogarelajes.azores.gov.pt/'},
#  'LPMA': {'id': 2343,
#   'iata': 'FNC',
#   'icao': 'LPMA',
#   'name': 'Madeira Airport',
#   'location': 'Funchal, Madeira, Portugal',
#   'street_number': '',
#   'street': '',
#   'city': 'Santa Cruz, Madeira',
#   'county': '',
#   'state': 'Madeira',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9100-105',
#   'phone': '+351 291 520 700',
#   'latitude': 32.695797,
#   'longitude': -16.775873,
#   'uct': 60,
#   'website': 'https://www.aeroportomadeira.pt/pt/fnc/home'},
#  'LPPS': {'id': 6207,
#   'iata': 'PXO',
#   'icao': 'LPPS',
#   'name': 'Porto Santo Airport',
#   'location': 'Porto Santo Island, Madeira, Portugal',
#   'street_number': '',
#   'street': '',
#   'city': '',
#   'county': '',
#   'state': 'Madeira',
#   'country_iso': 'PT',
#   'country': 'Portugal',
#   'postal_code': '9400-110',
#   'phone': '+351 291 980 120',
#   'latitude': 33.07494,
#   'longitude': -16.350033,
#   'uct': 60,
#   'website': 'https://www.ana.pt/en-US/Aeroportos/Madeira/PortoSanto/Pages/default.aspx'}}

# %%
airport_runways_dict
# Out:
# {'LPBJ': [{'name': '01L',
#    'trueHdg': 6.0,
#    'length': {'meter': 3457.96,
#     'km': 3.458,
#     'mile': 2.149,
#     'nm': 1.867,
#     'feet': 11345.0},
#    'width': {'meter': 60.05,
#     'km': 0.06,
#     'mile': 0.037,
#     'nm': 0.032,
#     'feet': 197.0},
#    'isClosed': False,
#    'location': {'lat': 38.063446, 'lon': -7.934465},
#    'surface': 'Concrete',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '01R',
#    'trueHdg': 5.9,
#    'length': {'meter': 2958.08,
#     'km': 2.958,
#     'mile': 1.838,
#     'nm': 1.597,
#     'feet': 9705.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 38.0654335, 'lon': -7.9317},
#    'surface': 'Concrete',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '19L',
#    'trueHdg': 185.9,
#    'length': {'meter': 2958.08,
#     'km': 2.958,
#     'mile': 1.838,
#     'nm': 1.597,
#     'feet': 9705.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 38.0918732, 'lon': -7.92822552},
#    'surface': 'Concrete',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '19R',
#    'trueHdg': 186.0,
#    'length': {'meter': 3457.96,
#     'km': 3.458,
#     'mile': 2.149,
#     'nm': 1.867,
#     'feet': 11345.0},
#    'width': {'meter': 60.05,
#     'km': 0.06,
#     'mile': 0.037,
#     'nm': 0.032,
#     'feet': 197.0},
#    'isClosed': False,
#    'location': {'lat': 38.09435, 'lon': -7.930364},
#    'surface': 'Concrete',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}],
#  'LPBR': [{'name': '07',
#    'trueHdg': 62.0,
#    'length': {'meter': 939.09,
#     'km': 0.939,
#     'mile': 0.584,
#     'nm': 0.507,
#     'feet': 3081.0},
#    'width': {'meter': 24.99,
#     'km': 0.025,
#     'mile': 0.016,
#     'nm': 0.013,
#     'feet': 82.0},
#    'isClosed': False,
#    'location': {'lat': 41.5850334, 'lon': -8.450158},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 149.96,
#     'km': 0.15,
#     'mile': 0.093,
#     'nm': 0.081,
#     'feet': 492.0},
#    'hasLighting': True},
#   {'name': '25',
#    'trueHdg': 242.0,
#    'length': {'meter': 939.09,
#     'km': 0.939,
#     'mile': 0.584,
#     'nm': 0.507,
#     'feet': 3081.0},
#    'width': {'meter': 24.99,
#     'km': 0.025,
#     'mile': 0.016,
#     'nm': 0.013,
#     'feet': 82.0},
#    'isClosed': False,
#    'location': {'lat': 41.58899, 'lon': -8.440188},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}],
#  'LPBG': [{'name': '02',
#    'trueHdg': 13.5,
#    'length': {'meter': 1702.92,
#     'km': 1.703,
#     'mile': 1.058,
#     'nm': 0.92,
#     'feet': 5587.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 41.8503571, 'lon': -6.70959425},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '20',
#    'trueHdg': 193.5,
#    'length': {'meter': 1702.92,
#     'km': 1.703,
#     'mile': 1.058,
#     'nm': 0.92,
#     'feet': 5587.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 41.8652344, 'lon': -6.704805},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}],
#  'LPCS': [],
#  'LPCH': [{'name': '16',
#    'trueHdg': 153.3,
#    'length': {'meter': 858.01,
#     'km': 0.858,
#     'mile': 0.533,
#     'nm': 0.463,
#     'feet': 2815.0},
#    'width': {'meter': 22.86,
#     'km': 0.023,
#     'mile': 0.014,
#     'nm': 0.012,
#     'feet': 75.0},
#    'isClosed': False,
#    'location': {'lat': 41.7255058, 'lon': -7.465124},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '34',
#    'trueHdg': 333.3,
#    'length': {'meter': 858.01,
#     'km': 0.858,
#     'mile': 0.533,
#     'nm': 0.463,
#     'feet': 2815.0},
#    'width': {'meter': 22.86,
#     'km': 0.023,
#     'mile': 0.014,
#     'nm': 0.012,
#     'feet': 75.0},
#    'isClosed': False,
#    'location': {'lat': 41.7186165, 'lon': -7.46047544},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}],
#  'LPCO': [{'name': '16',
#    'trueHdg': 157.1,
#    'length': {'meter': 919.89,
#     'km': 0.92,
#     'mile': 0.572,
#     'nm': 0.497,
#     'feet': 3018.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'surface': 'Unknown',
#    'hasLighting': False},
#   {'name': '34',
#    'trueHdg': 337.1,
#    'length': {'meter': 919.89,
#     'km': 0.92,
#     'mile': 0.572,
#     'nm': 0.497,
#     'feet': 3018.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'surface': 'Unknown',
#    'hasLighting': False}],
#  'LPIN': [],
#  'LPEV': [],
#  'LPFR': [{'name': '10',
#    'trueHdg': 100.1,
#    'length': {'meter': 2493.87,
#     'km': 2.494,
#     'mile': 1.55,
#     'nm': 1.347,
#     'feet': 8182.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 37.017292, 'lon': -7.986137},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'hasLighting': True},
#   {'name': '28',
#    'trueHdg': 280.1,
#    'length': {'meter': 2493.87,
#     'km': 2.494,
#     'mile': 1.55,
#     'nm': 1.347,
#     'feet': 8182.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 37.01337, 'lon': -7.958501},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'hasLighting': True}],
#  'LPVL': [],
#  'LPMI': [],
#  'LPMF': [],
#  'LPMO': [],
#  'LPPT': [{'name': '03',
#    'trueHdg': 22.7,
#    'length': {'meter': 3827.07,
#     'km': 3.827,
#     'mile': 2.378,
#     'nm': 2.066,
#     'feet': 12556.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 38.765625, 'lon': -9.144329},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 96.93,
#     'km': 0.097,
#     'mile': 0.06,
#     'nm': 0.052,
#     'feet': 318.0},
#    'hasLighting': True},
#   {'name': '17',
#    'trueHdg': 168.1,
#    'length': {'meter': 2322.88,
#     'km': 2.323,
#     'mile': 1.443,
#     'nm': 1.254,
#     'feet': 7621.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 38.78626, 'lon': -9.137281},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '21',
#    'trueHdg': 202.7,
#    'length': {'meter': 3827.07,
#     'km': 3.827,
#     'mile': 2.378,
#     'nm': 2.066,
#     'feet': 12556.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 38.79735, 'lon': -9.127334},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 602.89,
#     'km': 0.603,
#     'mile': 0.375,
#     'nm': 0.326,
#     'feet': 1978.0},
#    'hasLighting': True},
#   {'name': '35',
#    'trueHdg': 348.1,
#    'length': {'meter': 2322.88,
#     'km': 2.323,
#     'mile': 1.443,
#     'nm': 1.254,
#     'feet': 7621.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 38.76583, 'lon': -9.131763},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 60.05,
#     'km': 0.06,
#     'mile': 0.037,
#     'nm': 0.032,
#     'feet': 197.0},
#    'hasLighting': True}],
#  'LPPM': [{'name': '11',
#    'trueHdg': 107.5,
#    'length': {'meter': 858.93,
#     'km': 0.859,
#     'mile': 0.534,
#     'nm': 0.464,
#     'feet': 2818.0},
#    'width': {'meter': 27.13,
#     'km': 0.027,
#     'mile': 0.017,
#     'nm': 0.015,
#     'feet': 89.0},
#    'isClosed': False,
#    'location': {'lat': 37.15053, 'lon': -8.588586},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': False},
#   {'name': '29',
#    'trueHdg': 287.5,
#    'length': {'meter': 858.93,
#     'km': 0.859,
#     'mile': 0.534,
#     'nm': 0.464,
#     'feet': 2818.0},
#    'width': {'meter': 27.13,
#     'km': 0.027,
#     'mile': 0.017,
#     'nm': 0.015,
#     'feet': 89.0},
#    'isClosed': False,
#    'location': {'lat': 37.1482162, 'lon': -8.57935},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 89.0,
#     'km': 0.089,
#     'mile': 0.055,
#     'nm': 0.048,
#     'feet': 292.0},
#    'hasLighting': False}],
#  'LPPR': [{'name': '17',
#    'trueHdg': 168.8,
#    'length': {'meter': 3489.05,
#     'km': 3.489,
#     'mile': 2.168,
#     'nm': 1.884,
#     'feet': 11447.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 41.2633171, 'lon': -8.685252},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 302.97,
#     'km': 0.303,
#     'mile': 0.188,
#     'nm': 0.164,
#     'feet': 994.0},
#    'hasLighting': True},
#   {'name': '35',
#    'trueHdg': 348.8,
#    'length': {'meter': 3489.05,
#     'km': 3.489,
#     'mile': 2.168,
#     'nm': 1.884,
#     'feet': 11447.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 41.23256, 'lon': -8.677189},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 153.92,
#     'km': 0.154,
#     'mile': 0.096,
#     'nm': 0.083,
#     'feet': 505.0},
#    'hasLighting': True}],
#  'LPPV': [],
#  'LPSC': [],
#  'LPVR': [{'name': '02',
#    'trueHdg': 17.6,
#    'length': {'meter': 947.01,
#     'km': 0.947,
#     'mile': 0.588,
#     'nm': 0.511,
#     'feet': 3107.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 41.270298, 'lon': -7.722694},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '20',
#    'trueHdg': 197.6,
#    'length': {'meter': 947.01,
#     'km': 0.947,
#     'mile': 0.588,
#     'nm': 0.511,
#     'feet': 3107.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 41.2784157, 'lon': -7.719272},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}],
#  'LPVZ': [{'name': '01',
#    'trueHdg': 356.0,
#    'length': {'meter': 1223.77,
#     'km': 1.224,
#     'mile': 0.76,
#     'nm': 0.661,
#     'feet': 4015.0},
#    'width': {'meter': 29.57,
#     'km': 0.03,
#     'mile': 0.018,
#     'nm': 0.016,
#     'feet': 97.0},
#    'isClosed': True,
#    'surface': 'Unknown',
#    'hasLighting': False},
#   {'name': '18',
#    'trueHdg': 175.9,
#    'length': {'meter': 1222.86,
#     'km': 1.223,
#     'mile': 0.76,
#     'nm': 0.66,
#     'feet': 4012.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 40.73102, 'lon': -7.889602},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 57.91,
#     'km': 0.058,
#     'mile': 0.036,
#     'nm': 0.031,
#     'feet': 190.0},
#    'hasLighting': True},
#   {'name': '19',
#    'trueHdg': 176.0,
#    'length': {'meter': 1223.77,
#     'km': 1.224,
#     'mile': 0.76,
#     'nm': 0.661,
#     'feet': 4015.0},
#    'width': {'meter': 29.57,
#     'km': 0.03,
#     'mile': 0.018,
#     'nm': 0.016,
#     'feet': 97.0},
#    'isClosed': True,
#    'surface': 'Unknown',
#    'hasLighting': False},
#   {'name': '36',
#    'trueHdg': 355.9,
#    'length': {'meter': 1222.86,
#     'km': 1.223,
#     'mile': 0.76,
#     'nm': 0.66,
#     'feet': 4012.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 40.7200623, 'lon': -7.888558},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 64.01,
#     'km': 0.064,
#     'mile': 0.04,
#     'nm': 0.035,
#     'feet': 210.0},
#    'hasLighting': True}],
#  'LPAR': [],
#  'LPMR': [],
#  'LPMT': [],
#  'LPOT': [],
#  'LPOV': [],
#  'LP77': [],
#  'LPST': [],
#  'LPTN': [],
#  'LPCR': [{'name': '11',
#    'trueHdg': 96.5,
#    'length': {'meter': 761.09,
#     'km': 0.761,
#     'mile': 0.473,
#     'nm': 0.411,
#     'feet': 2497.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 39.67187, 'lon': -31.1211472},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': False},
#   {'name': '29',
#    'trueHdg': 276.5,
#    'length': {'meter': 761.09,
#     'km': 0.761,
#     'mile': 0.473,
#     'nm': 0.411,
#     'feet': 2497.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 39.6711, 'lon': -31.1123219},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': False}],
#  'LPHR': [{'name': '10',
#    'trueHdg': 89.7,
#    'length': {'meter': 1594.1,
#     'km': 1.594,
#     'mile': 0.991,
#     'nm': 0.861,
#     'feet': 5230.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 38.5198746, 'lon': -28.7250633},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '28',
#    'trueHdg': 269.7,
#    'length': {'meter': 1594.1,
#     'km': 1.594,
#     'mile': 0.991,
#     'nm': 0.861,
#     'feet': 5230.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 38.5199547, 'lon': -28.70676},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}],
#  'LPFL': [{'name': '18',
#    'trueHdg': 168.0,
#    'length': {'meter': 1435.0,
#     'km': 1.435,
#     'mile': 0.892,
#     'nm': 0.775,
#     'feet': 4708.0},
#    'width': {'meter': 39.93,
#     'km': 0.04,
#     'mile': 0.025,
#     'nm': 0.022,
#     'feet': 131.0},
#    'isClosed': False,
#    'location': {'lat': 39.4616966, 'lon': -31.1332531},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 78.94,
#     'km': 0.079,
#     'mile': 0.049,
#     'nm': 0.043,
#     'feet': 259.0},
#    'hasLighting': True},
#   {'name': '36',
#    'trueHdg': 348.0,
#    'length': {'meter': 1435.0,
#     'km': 1.435,
#     'mile': 0.892,
#     'nm': 0.775,
#     'feet': 4708.0},
#    'width': {'meter': 39.93,
#     'km': 0.04,
#     'mile': 0.025,
#     'nm': 0.022,
#     'feet': 131.0},
#    'isClosed': False,
#    'location': {'lat': 39.4490776, 'lon': -31.1297741},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 59.13,
#     'km': 0.059,
#     'mile': 0.037,
#     'nm': 0.032,
#     'feet': 194.0},
#    'hasLighting': True}],
#  'LPGR': [{'name': '09',
#    'trueHdg': 77.4,
#    'length': {'meter': 1266.14,
#     'km': 1.266,
#     'mile': 0.787,
#     'nm': 0.684,
#     'feet': 4154.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 39.0909, 'lon': -28.0369968},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '27',
#    'trueHdg': 257.4,
#    'length': {'meter': 1266.14,
#     'km': 1.266,
#     'mile': 0.787,
#     'nm': 0.684,
#     'feet': 4154.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 39.0933838, 'lon': -28.02269},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}],
#  'LPPI': [{'name': '09',
#    'trueHdg': 82.6,
#    'length': {'meter': 1738.88,
#     'km': 1.739,
#     'mile': 1.08,
#     'nm': 0.939,
#     'feet': 5705.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 38.5533066, 'lon': -28.4510784},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 74.07,
#     'km': 0.074,
#     'mile': 0.046,
#     'nm': 0.04,
#     'feet': 243.0},
#    'hasLighting': True},
#   {'name': '27',
#    'trueHdg': 262.6,
#    'length': {'meter': 1738.88,
#     'km': 1.739,
#     'mile': 1.08,
#     'nm': 0.939,
#     'feet': 5705.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 38.5553055, 'lon': -28.431263},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 89.0,
#     'km': 0.089,
#     'mile': 0.055,
#     'nm': 0.048,
#     'feet': 292.0},
#    'hasLighting': True}],
#  'LPAZ': [{'name': '04',
#    'trueHdg': 27.7,
#    'length': {'meter': 1324.36,
#     'km': 1.324,
#     'mile': 0.823,
#     'nm': 0.715,
#     'feet': 4345.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': True,
#    'surface': 'Unknown',
#    'hasLighting': False},
#   {'name': '15',
#    'trueHdg': 136.0,
#    'length': {'meter': 1830.02,
#     'km': 1.83,
#     'mile': 1.137,
#     'nm': 0.988,
#     'feet': 6004.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': True,
#    'surface': 'Unknown',
#    'hasLighting': False},
#   {'name': '18',
#    'trueHdg': 171.1,
#    'length': {'meter': 3063.85,
#     'km': 3.064,
#     'mile': 1.904,
#     'nm': 1.654,
#     'feet': 10052.0},
#    'width': {'meter': 60.05,
#     'km': 0.06,
#     'mile': 0.037,
#     'nm': 0.032,
#     'feet': 197.0},
#    'isClosed': False,
#    'location': {'lat': 36.9857941, 'lon': -25.17342},
#    'surface': 'Concrete',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '22',
#    'trueHdg': 207.7,
#    'length': {'meter': 1324.36,
#     'km': 1.324,
#     'mile': 0.823,
#     'nm': 0.715,
#     'feet': 4345.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': True,
#    'surface': 'Unknown',
#    'hasLighting': False},
#   {'name': '33',
#    'trueHdg': 316.0,
#    'length': {'meter': 1830.02,
#     'km': 1.83,
#     'mile': 1.137,
#     'nm': 0.988,
#     'feet': 6004.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': True,
#    'surface': 'Unknown',
#    'hasLighting': False},
#   {'name': '36',
#    'trueHdg': 351.1,
#    'length': {'meter': 3063.85,
#     'km': 3.064,
#     'mile': 1.904,
#     'nm': 1.654,
#     'feet': 10052.0},
#    'width': {'meter': 60.05,
#     'km': 0.06,
#     'mile': 0.037,
#     'nm': 0.032,
#     'feet': 197.0},
#    'isClosed': False,
#    'location': {'lat': 36.9586, 'lon': -25.1680737},
#    'surface': 'Concrete',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}],
#  'LPSJ': [{'name': '13',
#    'trueHdg': 117.3,
#    'length': {'meter': 1235.05,
#     'km': 1.235,
#     'mile': 0.767,
#     'nm': 0.667,
#     'feet': 4052.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 38.6680641, 'lon': -28.1819973},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 53.04,
#     'km': 0.053,
#     'mile': 0.033,
#     'nm': 0.029,
#     'feet': 174.0},
#    'hasLighting': True},
#   {'name': '31',
#    'trueHdg': 297.3,
#    'length': {'meter': 1235.05,
#     'km': 1.235,
#     'mile': 0.767,
#     'nm': 0.667,
#     'feet': 4052.0},
#    'width': {'meter': 29.87,
#     'km': 0.03,
#     'mile': 0.019,
#     'nm': 0.016,
#     'feet': 98.0},
#    'isClosed': False,
#    'location': {'lat': 38.6629829, 'lon': -28.169363},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 50.9,
#     'km': 0.051,
#     'mile': 0.032,
#     'nm': 0.027,
#     'feet': 167.0},
#    'hasLighting': True}],
#  'LPPD': [{'name': '12',
#    'trueHdg': 111.6,
#    'length': {'meter': 2513.08,
#     'km': 2.513,
#     'mile': 1.562,
#     'nm': 1.357,
#     'feet': 8245.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 37.7461548, 'lon': -25.71089},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 28.04,
#     'km': 0.028,
#     'mile': 0.017,
#     'nm': 0.015,
#     'feet': 92.0},
#    'hasLighting': True},
#   {'name': '30',
#    'trueHdg': 291.6,
#    'length': {'meter': 2513.08,
#     'km': 2.513,
#     'mile': 1.562,
#     'nm': 1.357,
#     'feet': 8245.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 37.73783, 'lon': -25.68435},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 235.0,
#     'km': 0.235,
#     'mile': 0.146,
#     'nm': 0.127,
#     'feet': 771.0},
#    'hasLighting': True}],
#  'LPLA': [{'name': '15',
#    'trueHdg': 140.8,
#    'length': {'meter': 3312.87,
#     'km': 3.313,
#     'mile': 2.059,
#     'nm': 1.789,
#     'feet': 10869.0},
#    'width': {'meter': 60.66,
#     'km': 0.061,
#     'mile': 0.038,
#     'nm': 0.033,
#     'feet': 199.0},
#    'isClosed': False,
#    'location': {'lat': 38.7759857, 'lon': -27.10559},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '33',
#    'trueHdg': 320.8,
#    'length': {'meter': 3312.87,
#     'km': 3.313,
#     'mile': 2.059,
#     'nm': 1.789,
#     'feet': 10869.0},
#    'width': {'meter': 60.66,
#     'km': 0.061,
#     'mile': 0.038,
#     'nm': 0.033,
#     'feet': 199.0},
#    'isClosed': False,
#    'location': {'lat': 38.75291, 'lon': -27.0814686},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}],
#  'LPMA': [{'name': '05',
#    'trueHdg': 44.6,
#    'length': {'meter': 2784.96,
#     'km': 2.785,
#     'mile': 1.73,
#     'nm': 1.504,
#     'feet': 9137.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 32.6889725, 'lon': -16.7848778},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 146.91,
#     'km': 0.147,
#     'mile': 0.091,
#     'nm': 0.079,
#     'feet': 482.0},
#    'hasLighting': True},
#   {'name': '23',
#    'trueHdg': 224.6,
#    'length': {'meter': 2784.96,
#     'km': 2.785,
#     'mile': 1.73,
#     'nm': 1.504,
#     'feet': 9137.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 32.7068062, 'lon': -16.7640133},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 145.08,
#     'km': 0.145,
#     'mile': 0.09,
#     'nm': 0.078,
#     'feet': 476.0},
#    'hasLighting': True}],
#  'LPPS': [{'name': '18',
#    'trueHdg': 178.1,
#    'length': {'meter': 3016.91,
#     'km': 3.017,
#     'mile': 1.875,
#     'nm': 1.629,
#     'feet': 9898.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 33.0869331, 'lon': -16.350481},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True},
#   {'name': '36',
#    'trueHdg': 358.1,
#    'length': {'meter': 3016.91,
#     'km': 3.017,
#     'mile': 1.875,
#     'nm': 1.629,
#     'feet': 9898.0},
#    'width': {'meter': 45.11,
#     'km': 0.045,
#     'mile': 0.028,
#     'nm': 0.024,
#     'feet': 148.0},
#    'isClosed': False,
#    'location': {'lat': 33.059845, 'lon': -16.3494129},
#    'surface': 'Asphalt',
#    'displacedThreshold': {'meter': 0.0,
#     'km': 0.0,
#     'mile': 0.0,
#     'nm': 0.0,
#     'feet': 0.0},
#    'hasLighting': True}]}

# %%
airport_schedules_status_dict
# Out:
# {'LPBJ': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPBR': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPBG': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPCH': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPCO': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPFR': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-03'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates', 'status': 'OK'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Down'}},
#  'LPPT': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-03'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates', 'status': 'OK'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'OKPartial'}},
#  'LPPM': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-10-18',
#    'maxAvailableLocalDate': '2021-04-29'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'OKPartial'}},
#  'LPPR': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-03'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates', 'status': 'OK'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPVR': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPVZ': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPCR': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPHR': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-03'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates', 'status': 'OK'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPFL': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-03'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates', 'status': 'OK'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPGR': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPPI': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPAZ': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-03'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates', 'status': 'OK'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPSJ': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'Unavailable'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPPD': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-03'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates', 'status': 'OK'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPLA': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-03'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates',
#    'status': 'Unavailable'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}},
#  'LPMA': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-03'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates', 'status': 'OK'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Down'}},
#  'LPPS': {'flightSchedulesFeed': {'service': 'FlightSchedules',
#    'status': 'OK',
#    'minAvailableLocalDate': '2020-06-23',
#    'maxAvailableLocalDate': '2021-08-01'},
#   'liveFlightUpdatesFeed': {'service': 'FlightLiveUpdates', 'status': 'OK'},
#   'adsbUpdatesFeed': {'service': 'AdsbUpdates', 'status': 'Unavailable'}}}

# %% [markdown]
# #### Save the airports' runways and schedules' availability status in a JSON file

# %%
def write_json_file(filename, data):
    """
    Summary: Writes data to a JSON file. If the file does not exist, it is created.
    Params: 'filename' - The name of the file.
            'data' - The data.
    """
    with open(filename, 'w') as json_file:
        json.dump(data, json_file)

write_json_file('airport-runways.json', airport_runways_dict)
write_json_file('airport-schedules-status.json', airport_schedules_status_dict)

# %% [markdown]
# #### Handle airports' information with Dataframes

# %%
# Merge basic airports' info from web scraping with more details from the information endpoint

non_required_feats = ['id', 'iata', 'name', 'location', 'city', 'error']
airport_new_data = pd.DataFrame(airport_info_dict).T.drop(labels=non_required_feats, axis=1)

airports_details = pd.merge(airports, airport_new_data, how='left', on='icao')
airports_details
# Out:
#     icao  iata                city    region  \
# 0   LPBJ   BYJ                Beja  Alentejo
# 1   LPBR   BGZ               Braga     Norte
# 2   LPBG   BGC            Bragança     Norte
# 3   LPCS   CAT             Cascais    Lisboa
# 4   LPCH   CHV              Chaves     Norte
# 5   LPCO   CBP             Coimbra    Centro
# 6   LPIN  None             Espinho     Norte
# 7   LPEV  None               Évora  Alentejo
# 8   LPFR   FAO                Faro   Algarve
# 9   LPVL  None                Maia     Norte
# 10  LPMI  None           Mirandela     Norte
# 11  LPMF  None         Monfortinho    Centro
# 12  LPMO   QLR           Montargil  Alentejo
# 13  LPPT   LIS              Lisbon    Lisboa
# 14  LPPM   PRM            Portimão   Algarve
# 15  LPPR   OPO               Porto     Norte
# 16  LPPV  None        Castro Marim   Algarve
# 17  LPSC  None          Santa Cruz    Centro
# 18  LPVR   VRL           Vila Real     Norte
# 19  LPVZ   VSE               Viseu    Centro
# 20  LPAR  None             Alverca    Lisboa
# 21  LPMR  None          Monte Real    Centro
# 22  LPMT   PAF             Montijo    Lisboa
# 23  LPOT  None                 Ota    Centro
# 24  LPOV  None                Ovar    Centro
# 25  LP77  None     Santa Margarida    Centro
# 26  LPST  None              Sintra    Lisboa
# 27  LPTN  None              Tancos    Centro
# 28  LPCR   CVU        Corvo Island    Azores
# 29  LPHR   HOR        Faial Island    Azores
# 30  LPFL   FLW       Flores Island    Azores
# 31  LPGR   GRW     Graciosa Island    Azores
# 32  LPPI   PIX         Pico Island    Azores
# 33  LPAZ   SMA         Santa Maria    Azores
# 34  LPSJ   SJZ    São Jorge Island    Azores
# 35  LPPD   PDL   São Miguel Island    Azores
# 36  LPLA   TER     Terceira Island    Azores
# 37  LPMA   FNC      Madeira Island   Madeira
# 38  LPPS   PXO  Porto Santo Island   Madeira
#
#                           description street_number  \
# 0                        Beja Airport
# 1                       Braga Airport
# 2                    Bragança Airport
# 3     Lisbon-Cascais Regional Airport
# 4                      Chaves Airport           S/N
# 5                     Coimbra Airport
# 6                     Espinho Airport           NaN
# 7                       Évora Airport           NaN
# 8                        Faro Airport
# 9                        Maia Airport           NaN
# 10                  Mirandela Airport           NaN
# 11                Monfortinho Airport           NaN
# 12                   Morargil Airport           NaN
# 13                     Lisbon Airport
# 14                   Portimão Airport
# 15      Francisco Sá Carneiro Airport
# 16                Praia Verde Airport           NaN
# 17                 Santa Cruz Airport           NaN
# 18                  Vila Real Airport
# 19                      Viseu Airport
# 20                    Alverca Airbase           NaN
# 21                Monte Real Air Base           NaN
# 22                    Montijo Airbase           NaN
# 23                        Ota Airbase           NaN
# 24                       Ovar Airbase           NaN
# 25       Santa Margarida Army Airbase           NaN
# 26                     Sintra Airbase           NaN
# 27                     Tancos Airbase           NaN
# 28                      Corvo Airport
# 29                      Horta Airport
# 30                     Flores Airport
# 31                   Graciosa Airport
# 32                       Pico Airport
# 33                Santa Maria Airport          3249
# 34                  São Jorge Airport
# 35              João Paulo II Airport
# 36                     Lajes Air Base
# 37  Cristiano Ronaldo Madeira Airport
# 38                Porto Santo Airport
#
#                                  street                county  \
# 0
# 1                       Rua do Carregal
# 2                 Aeródromo de Bragança
# 3
# 4                  Rua Dom Gualdim Pais
# 5                         Estrada Ponte
# 6                                   NaN                   NaN
# 7                                   NaN                   NaN
# 8
# 9                                   NaN                   NaN
# 10                                  NaN                   NaN
# 11                                  NaN                   NaN
# 12                                  NaN                   NaN
# 13  Alameda das Comunidades Portuguesas
# 14
# 15
# 16                                  NaN                   NaN
# 17                                  NaN                   NaN
# 18
# 19                    Avenida Aeródromo
# 20                                  NaN                   NaN
# 21                                  NaN                   NaN
# 22                                  NaN                   NaN
# 23                                  NaN                   NaN
# 24                                  NaN                   NaN
# 25                                  NaN                   NaN
# 26                                  NaN                   NaN
# 27                                  NaN                   NaN
# 28            Corvo - V. Corvo - Flores
# 29                       Castelo Branco
# 30
# 31                                EN1-2
# 32                            Bandeiras
# 33                       Terminal Drive  Santa Barbara County
# 34                                  EN1
# 35           Aeroporto de Ponta Delgada
# 36             Aerogare Civil das Lajes
# 37
# 38
#
#                  state country_iso        country postal_code  \
# 0                 Beja          PT       Portugal    7780-745
# 1                Braga          PT       Portugal    4700-688
# 2             Bragança          PT       Portugal    5300-000
# 3               Lisboa          PT       Portugal        2785
# 4            Vila Real          PT       Portugal    5400-298
# 5              Coimbra          PT       Portugal    3040-575
# 6                  NaN         NaN            NaN         NaN
# 7                  NaN         NaN            NaN         NaN
# 8        Faro District          PT       Portugal    8001-701
# 9                  NaN         NaN            NaN         NaN
# 10                 NaN         NaN            NaN         NaN
# 11                 NaN         NaN            NaN         NaN
# 12                 NaN         NaN            NaN         NaN
# 13              Lisboa          PT       Portugal    1700-111
# 14                Faro          PT       Portugal    8500-059
# 15      Porto District          PT       Portugal    4470-558
# 16                 NaN         NaN            NaN         NaN
# 17                 NaN         NaN            NaN         NaN
# 18  Vila Real District          PT       Portugal        5000
# 19               Viseu          PT       Portugal        3515
# 20                 NaN         NaN            NaN         NaN
# 21                 NaN         NaN            NaN         NaN
# 22                 NaN         NaN            NaN         NaN
# 23                 NaN         NaN            NaN         NaN
# 24                 NaN         NaN            NaN         NaN
# 25                 NaN         NaN            NaN         NaN
# 26                 NaN         NaN            NaN         NaN
# 27                 NaN         NaN            NaN         NaN
# 28              Açores          PT       Portugal    9980-000
# 29              Açores          PT       Portugal    9900-321
# 30              Azores          PT       Portugal    9970-320
# 31              Açores          PT       Portugal        9880
# 32              Açores          PT       Portugal    9950-011
# 33          California          US  United States       93455
# 34              Açores          PT       Portugal        9800
# 35              Açores          PT       Portugal    9500-749
# 36    Ilha de Terceira          PT       Portugal    9760-251
# 37             Madeira          PT       Portugal    9100-105
# 38             Madeira          PT       Portugal    9400-110
#
#                phone latitude longitude   uct  \
# 0   +351 284 001 020  38.0637   -7.9393    60
# 1   +351 253 626 530   41.587  -8.44293    60
# 2   +351 273 381 175  41.8572  -6.70726    60
# 3   +351 21 445 7300  38.7219  -9.35361    60
# 4   +351 276 321 995  41.7251  -7.46632    60
# 5   +351 239 947 235  40.1591  -8.47104    60
# 6                NaN      NaN       NaN   NaN
# 7                NaN      NaN       NaN   NaN
# 8   +351 289 800 800  37.0176  -7.96972    60
# 9                NaN      NaN       NaN   NaN
# 10               NaN      NaN       NaN   NaN
# 11               NaN      NaN       NaN   NaN
# 12               NaN      NaN       NaN   NaN
# 13  +351 21 841 3500  38.7756  -9.13537    60
# 14  +351 932 001 009  37.1477  -8.58011    60
# 15  +351 22 943 2400  41.2421  -8.67855    60
# 16               NaN      NaN       NaN   NaN
# 17               NaN      NaN       NaN   NaN
# 18  +351 259 336 620  41.2758  -7.71944    60
# 19  +351 232 459 849  40.7273  -7.89052    60
# 20               NaN      NaN       NaN   NaN
# 21               NaN      NaN       NaN   NaN
# 22               NaN      NaN       NaN   NaN
# 23               NaN      NaN       NaN   NaN
# 24               NaN      NaN       NaN   NaN
# 25               NaN      NaN       NaN   NaN
# 26               NaN      NaN       NaN   NaN
# 27               NaN      NaN       NaN   NaN
# 28  +351 292 590 310  39.6707  -31.1133     0
# 29  +351 292 943 511    38.52  -28.7164     0
# 30  +351 800 201 201  39.4594  -31.1313     0
# 31  +351 296 209 748  39.0918  -28.0318     0
# 32  +351 292 628 380  38.5523  -28.4433     0
# 33   +1 805-922-1726  34.8991  -120.448  -420
# 34                    38.6656  -28.1757     0
# 35  +351 296 205 400  37.7423  -25.7004     0
# 36  +351 295 545 454  38.7539  -27.0869     0
# 37  +351 291 520 700  32.6958  -16.7759    60
# 38  +351 291 980 120  33.0749    -16.35    60
#
#                                               website
# 0
# 1                          https://aeroclubebraga.pt/
# 2                https://www.cm-braganca.pt/pages/125
# 3                        http://aerodromo-cascais.pt/
# 4                      http://www.chaves.pt/pages/439
# 5
# 6                                                 NaN
# 7                                                 NaN
# 8   http://www.ana.pt/pt-PT/Aeroportos/Algarve/Far...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  http://www.ana.pt/pt-PT/Aeroportos/Lisboa/Lisb...
# 14                        http://www.airemotions.com/
# 15  http://www.ana.pt/pt-PT/Aeroportos/Porto/Porto...
# 16                                                NaN
# 17                                                NaN
# 18
# 19                           https://www.cm-viseu.pt/
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                http://www.sata.pt/
# 29  http://www.ana.pt/pt-PT/Aeroportos/Acores/Hort...
# 30  http://www.ana.pt/pt-PT/Aeroportos/Acores/Flor...
# 31
# 32
# 33                  http://www.santamariaairport.com/
# 34
# 35              https://www.aeroportopontadelgada.pt/
# 36                http://aerogarelajes.azores.gov.pt/
# 37        https://www.aeroportomadeira.pt/pt/fnc/home
# 38  https://www.ana.pt/en-US/Aeroportos/Madeira/Po...

# %% [markdown]
# #### Persist airports' detailed information in a newly created Airports table

# %%
conn = sqlite3.connect('airports.db')
cur = conn.cursor()

# Drop any previous Airports table - to allow the demonstration of the notebook - and create a new one

q = """
    DROP TABLE IF EXISTS Airports;
"""
cur.execute(q)

q = """
    CREATE TABLE Airports(
        Icao TEXT PRIMARY KEY,
        Iata TEXT,
        City TEXT,
        Region TEXT,
        Description TEXT,
        Street_Number TEXT,
        Street TEXT,
        County TEXT,
        State TEXT,
        Country_Iso TEXT,
        Country TEXT,
        Postal_Code TEXT,
        Phone TEXT,
        Latitude TEXT,
        Longitude TEXT,
        Uct TEXT,
        Website TEXT);
"""
cur.execute(q)

# %%
# Persist the 'airports_details' dataframe into the database - Airports table

airports_details.to_sql('Airports', con=conn, if_exists='append', index=False)

# %%
# Read all the data in the table Airports into a dataframe, to check the written information

q = """
    SELECT * 
    FROM Airports
"""
cur.execute(q)

sql_result = cur.fetchall()
pd.DataFrame(sql_result)
# Out:
#        0     1                   2         3  \
# 0   LPBJ   BYJ                Beja  Alentejo
# 1   LPBR   BGZ               Braga     Norte
# 2   LPBG   BGC            Bragança     Norte
# 3   LPCS   CAT             Cascais    Lisboa
# 4   LPCH   CHV              Chaves     Norte
# 5   LPCO   CBP             Coimbra    Centro
# 6   LPIN  None             Espinho     Norte
# 7   LPEV  None               Évora  Alentejo
# 8   LPFR   FAO                Faro   Algarve
# 9   LPVL  None                Maia     Norte
# 10  LPMI  None           Mirandela     Norte
# 11  LPMF  None         Monfortinho    Centro
# 12  LPMO   QLR           Montargil  Alentejo
# 13  LPPT   LIS              Lisbon    Lisboa
# 14  LPPM   PRM            Portimão   Algarve
# 15  LPPR   OPO               Porto     Norte
# 16  LPPV  None        Castro Marim   Algarve
# 17  LPSC  None          Santa Cruz    Centro
# 18  LPVR   VRL           Vila Real     Norte
# 19  LPVZ   VSE               Viseu    Centro
# 20  LPAR  None             Alverca    Lisboa
# 21  LPMR  None          Monte Real    Centro
# 22  LPMT   PAF             Montijo    Lisboa
# 23  LPOT  None                 Ota    Centro
# 24  LPOV  None                Ovar    Centro
# 25  LP77  None     Santa Margarida    Centro
# 26  LPST  None              Sintra    Lisboa
# 27  LPTN  None              Tancos    Centro
# 28  LPCR   CVU        Corvo Island    Azores
# 29  LPHR   HOR        Faial Island    Azores
# 30  LPFL   FLW       Flores Island    Azores
# 31  LPGR   GRW     Graciosa Island    Azores
# 32  LPPI   PIX         Pico Island    Azores
# 33  LPAZ   SMA         Santa Maria    Azores
# 34  LPSJ   SJZ    São Jorge Island    Azores
# 35  LPPD   PDL   São Miguel Island    Azores
# 36  LPLA   TER     Terceira Island    Azores
# 37  LPMA   FNC      Madeira Island   Madeira
# 38  LPPS   PXO  Porto Santo Island   Madeira
#
#                                     4     5  \
# 0                        Beja Airport
# 1                       Braga Airport
# 2                    Bragança Airport
# 3     Lisbon-Cascais Regional Airport
# 4                      Chaves Airport   S/N
# 5                     Coimbra Airport
# 6                     Espinho Airport  None
# 7                       Évora Airport  None
# 8                        Faro Airport
# 9                        Maia Airport  None
# 10                  Mirandela Airport  None
# 11                Monfortinho Airport  None
# 12                   Morargil Airport  None
# 13                     Lisbon Airport
# 14                   Portimão Airport
# 15      Francisco Sá Carneiro Airport
# 16                Praia Verde Airport  None
# 17                 Santa Cruz Airport  None
# 18                  Vila Real Airport
# 19                      Viseu Airport
# 20                    Alverca Airbase  None
# 21                Monte Real Air Base  None
# 22                    Montijo Airbase  None
# 23                        Ota Airbase  None
# 24                       Ovar Airbase  None
# 25       Santa Margarida Army Airbase  None
# 26                     Sintra Airbase  None
# 27                     Tancos Airbase  None
# 28                      Corvo Airport
# 29                      Horta Airport
# 30                     Flores Airport
# 31                   Graciosa Airport
# 32                       Pico Airport
# 33                Santa Maria Airport  3249
# 34                  São Jorge Airport
# 35              João Paulo II Airport
# 36                     Lajes Air Base
# 37  Cristiano Ronaldo Madeira Airport
# 38                Porto Santo Airport
#
#                                       6                     7  \
# 0
# 1                       Rua do Carregal
# 2                 Aeródromo de Bragança
# 3
# 4                  Rua Dom Gualdim Pais
# 5                         Estrada Ponte
# 6                                  None                  None
# 7                                  None                  None
# 8
# 9                                  None                  None
# 10                                 None                  None
# 11                                 None                  None
# 12                                 None                  None
# 13  Alameda das Comunidades Portuguesas
# 14
# 15
# 16                                 None                  None
# 17                                 None                  None
# 18
# 19                    Avenida Aeródromo
# 20                                 None                  None
# 21                                 None                  None
# 22                                 None                  None
# 23                                 None                  None
# 24                                 None                  None
# 25                                 None                  None
# 26                                 None                  None
# 27                                 None                  None
# 28            Corvo - V. Corvo - Flores
# 29                       Castelo Branco
# 30
# 31                                EN1-2
# 32                            Bandeiras
# 33                       Terminal Drive  Santa Barbara County
# 34                                  EN1
# 35           Aeroporto de Ponta Delgada
# 36             Aerogare Civil das Lajes
# 37
# 38
#
#                      8     9             10        11                12  \
# 0                 Beja    PT       Portugal  7780-745  +351 284 001 020
# 1                Braga    PT       Portugal  4700-688  +351 253 626 530
# 2             Bragança    PT       Portugal  5300-000  +351 273 381 175
# 3               Lisboa    PT       Portugal      2785  +351 21 445 7300
# 4            Vila Real    PT       Portugal  5400-298  +351 276 321 995
# 5              Coimbra    PT       Portugal  3040-575  +351 239 947 235
# 6                 None  None           None      None              None
# 7                 None  None           None      None              None
# 8        Faro District    PT       Portugal  8001-701  +351 289 800 800
# 9                 None  None           None      None              None
# 10                None  None           None      None              None
# 11                None  None           None      None              None
# 12                None  None           None      None              None
# 13              Lisboa    PT       Portugal  1700-111  +351 21 841 3500
# 14                Faro    PT       Portugal  8500-059  +351 932 001 009
# 15      Porto District    PT       Portugal  4470-558  +351 22 943 2400
# 16                None  None           None      None              None
# 17                None  None           None      None              None
# 18  Vila Real District    PT       Portugal      5000  +351 259 336 620
# 19               Viseu    PT       Portugal      3515  +351 232 459 849
# 20                None  None           None      None              None
# 21                None  None           None      None              None
# 22                None  None           None      None              None
# 23                None  None           None      None              None
# 24                None  None           None      None              None
# 25                None  None           None      None              None
# 26                None  None           None      None              None
# 27                None  None           None      None              None
# 28              Açores    PT       Portugal  9980-000  +351 292 590 310
# 29              Açores    PT       Portugal  9900-321  +351 292 943 511
# 30              Azores    PT       Portugal  9970-320  +351 800 201 201
# 31              Açores    PT       Portugal      9880  +351 296 209 748
# 32              Açores    PT       Portugal  9950-011  +351 292 628 380
# 33          California    US  United States     93455   +1 805-922-1726
# 34              Açores    PT       Portugal      9800
# 35              Açores    PT       Portugal  9500-749  +351 296 205 400
# 36    Ilha de Terceira    PT       Portugal  9760-251  +351 295 545 454
# 37             Madeira    PT       Portugal  9100-105  +351 291 520 700
# 38             Madeira    PT       Portugal  9400-110  +351 291 980 120
#
#            13          14    15  \
# 0   38.063667  -7.9393034    60
# 1   41.586994   -8.442929    60
# 2    41.85719    -6.70726    60
# 3   38.721943   -9.353611    60
# 4    41.72512  -7.4663243    60
# 5    40.15911   -8.471043    60
# 6        None        None  None
# 7        None        None  None
# 8   37.017597    -7.96972    60
# 9        None        None  None
# 10       None        None  None
# 11       None        None  None
# 12       None        None  None
# 13  38.775593   -9.135366    60
# 14  37.147663   -8.580112    60
# 15   41.24212   -8.678552    60
# 16       None        None  None
# 17       None        None  None
# 18  41.275814   -7.719441    60
# 19  40.727264  -7.8905206    60
# 20       None        None  None
# 21       None        None  None
# 22       None        None  None
# 23       None        None  None
# 24       None        None  None
# 25       None        None  None
# 26       None        None  None
# 27       None        None  None
# 28   39.67065  -31.113253     0
# 29      38.52  -28.716389     0
# 30  39.459354  -31.131304     0
# 31   39.09181  -28.031773     0
# 32   38.55235  -28.443344     0
# 33   34.89914  -120.44778  -420
# 34   38.66562  -28.175667     0
# 35   37.74233  -25.700388     0
# 36   38.75388  -27.086943     0
# 37  32.695797  -16.775873    60
# 38   33.07494  -16.350033    60
#
#                                                    16
# 0
# 1                          https://aeroclubebraga.pt/
# 2                https://www.cm-braganca.pt/pages/125
# 3                        http://aerodromo-cascais.pt/
# 4                      http://www.chaves.pt/pages/439
# 5
# 6                                                None
# 7                                                None
# 8   http://www.ana.pt/pt-PT/Aeroportos/Algarve/Far...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  http://www.ana.pt/pt-PT/Aeroportos/Lisboa/Lisb...
# 14                        http://www.airemotions.com/
# 15  http://www.ana.pt/pt-PT/Aeroportos/Porto/Porto...
# 16                                               None
# 17                                               None
# 18
# 19                           https://www.cm-viseu.pt/
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                http://www.sata.pt/
# 29  http://www.ana.pt/pt-PT/Aeroportos/Acores/Hort...
# 30  http://www.ana.pt/pt-PT/Aeroportos/Acores/Flor...
# 31
# 32
# 33                  http://www.santamariaairport.com/
# 34
# 35              https://www.aeroportopontadelgada.pt/
# 36                http://aerogarelajes.azores.gov.pt/
# 37        https://www.aeroportomadeira.pt/pt/fnc/home
# 38  https://www.ana.pt/en-US/Aeroportos/Madeira/Po...

# %%
conn.close()
